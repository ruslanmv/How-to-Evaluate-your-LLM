# %%
import pandas as pd

# Example reference and prediction messages
reference = [
    "The weather today is sunny and warm.",
    "I enjoyed reading that book last night.",
    "The concert was amazing!",
    "She is a talented musician.",
    "The movie was full of suspense.",
    "The team won the championship.",
    "I love eating pizza on weekends.",
    "The painting was beautifully done.",
    "He is a brilliant scientist.",
    "The new album is a masterpiece.",
    "I had a great time at the beach.",
    "The play was well-acted and engaging.",
    "The recipe is easy to follow.",
    "She has a lovely singing voice.",
    "The city skyline is breathtaking.",
    "The novel kept me hooked until the end.",
    "The dance performance was mesmerizing.",
    "The museum exhibits were fascinating.",
    "The coffee shop has a cozy atmosphere.",
    "I enjoy hiking in the mountains."
]

prediction = [
    "The weather tomorrow will be cloudy.",
    "I plan to finish that book this weekend.",
    "The concert was disappointing.",
    "She needs more practice as a musician.",
    "The movie was predictable and boring.",
    "The team lost the game.",
    "I prefer pasta over pizza.",
    "The painting lacked creativity.",
    "He made a major scientific breakthrough.",
    "The new album is a letdown.",
    "I wish I could go to the beach.",
    "The play was dull and uninteresting.",
    "The recipe requires many ingredients.",
    "She should take singing lessons.",
    "The city skyline is under construction.",
    "The novel was difficult to follow.",
    "The dance performance was lackluster.",
    "The museum exhibits were disappointing.",
    "The coffee shop has poor service.",
    "I find hiking exhausting."
]

# Create the dataframe
data = {'reference': reference, 'prediction': prediction}
df = pd.DataFrame(data)

# Print the dataframe
print(df)
# Out:
#                                   reference  \
# 0      The weather today is sunny and warm.
# 1   I enjoyed reading that book last night.
# 2                  The concert was amazing!
# 3               She is a talented musician.
# 4           The movie was full of suspense.
# 5            The team won the championship.
# 6          I love eating pizza on weekends.
# 7        The painting was beautifully done.
# 8              He is a brilliant scientist.
# 9           The new album is a masterpiece.
# 10         I had a great time at the beach.
# 11    The play was well-acted and engaging.
# 12            The recipe is easy to follow.
# 13          She has a lovely singing voice.
# 14        The city skyline is breathtaking.
# 15  The novel kept me hooked until the end.
# 16   The dance performance was mesmerizing.
# 17    The museum exhibits were fascinating.
# 18   The coffee shop has a cozy atmosphere.
# 19         I enjoy hiking in the mountains.
#
# ...
